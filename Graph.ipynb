# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Data.csv")

# %%
dataset
# Out:
#       Month  sales  Expenses  profit
# 0   January   1000       400     600
# 1  February   1500       500    1000
# 2     March   1200       450     750
# 3     April   1700       600    1100
# 4       May   1600       550    1050
# 5      June   1800       650    1150

# %%
dataset.columns
# Out:
# Index(['Month', 'sales', 'Expenses', 'profit'], dtype='object')

# %%
x_axis=dataset.columns[0]

# %%
y_axis=dataset.columns[3]

# %%
plt.plot(dataset[x_axis], dataset[y_axis], linestyle='-', color="blue")
plt.title("graph")
plt.xlabel("Month")
plt.ylabel("Profit")
plt.grid(True)
plt.show()
